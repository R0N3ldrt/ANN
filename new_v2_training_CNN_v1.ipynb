# %% [markdown]
# <a href="https://colab.research.google.com/github/R0N3ldrt/Thesis/blob/main/new_v2_training_CNN_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Traininig NN Spectrum

# %% [markdown]
# # Loading Necesary Libraries

# %%
# Importing necesary libraries
# Libraries for correct code execution 

import os, time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import pickle
import random
import csv
import re
import array
import seaborn as sns
from tqdm import tqdm

from functools import reduce
from random import random, gauss
from math import modf, pi, cos, sin, sqrt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from plotly.subplots import make_subplots
from scipy.signal import savgol_filter
from scipy.stats.stats import pearsonr
from scipy.stats import spearmanr

import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

from keras.models import Sequential
from keras.layers import Dense,Conv2D, Flatten
from keras.wrappers.scikit_learn import KerasRegressor
from keras.callbacks import EarlyStopping
from sklearn.mixture import GaussianMixture
import os, time, math, csv, joblib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.mixture import GaussianMixture

import os, time, math, csv, joblib
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.mixture import GaussianMixture

import warnings
warnings.filterwarnings("ignore")

sns.set_theme()

# %% [markdown]
# # Load Enviroment

# %%
# BLOQUE PARA USAR DESDE COLAB

# Google drive loading as work station for local-usage of the files.
from google.colab import drive
drive.mount('/content/gdrive',force_remount= True)

#-----------------------------------------------------------------------------
# Out:
# Mounted at /content/gdrive

# %%
# Lista para cambiar los paths rapido.
workers = ["Ronald", "Local"]

# Change the number to change the paths.
worker = workers[0]

if worker == "Ronald":
  path = "/content/gdrive/MyDrive/Thesis_Workstation/ANN_dataset"
else: path = os.getcwd()

# %% [markdown]
# # Create training/testing df

# %%
def rand(start, end, num): # get random value function
    res = []
    for j in range(num):
        res.append(np.random.randint(start, end))
    return res

# %%
def calc_freq_behavior(working_df, selected_point, multi=False): # Individual freq calculator
  extra_data = working_df.iloc[:, 0:6]
  freq_selected = working_df.iloc[:, selected_point+6]

  freq_data_df = pd.merge(extra_data, freq_selected, left_index=True, right_index=True)
  freq_data_df['Distance_km'] = freq_data_df['Distance_km'].astype(int)

  headers = list(freq_data_df.columns.values)
  selected_val = round(float(headers[-1]), 5)

  distances = [x*80 for x in range(1, 26)]
  freq_behavior = {}
  f_behavior = {}

  for dist in distances: # loop all distances available

    distance_df = freq_data_df[(freq_data_df['Distance_km'] == dist)] # select all the row with current eval distance
    freq_distance_vals = distance_df[str(selected_val)].tolist()

    freq_mean = np.mean(freq_distance_vals)
    freq_std = np.std(freq_distance_vals)
    results = (freq_mean, freq_std)
    f_behavior[dist] = results

  freq_behavior[selected_val] = f_behavior
  return freq_behavior

# %%
def select_eval_cols(working_df, eval_cols_param): # retturn index of column to be evaluated
  if eval_cols_param[0] == 'even': 
    break_point = int((working_df.shape[1]-6)/(eval_cols_param[1]+1))
    selected_cols = []
    for col_idx in range(1, eval_cols_param[1]+1):
      selected_cols.append((col_idx*break_point)-1)
  else:
    selected_cols = rand(1, working_df.shape[1]-6, eval_cols_param[1])
    selected_cols = sorted(selected_cols)
  return selected_cols

# %%
# multi_params = (method, number_freq_to_analyze)
def multiple_freq_analyzer(working_df, multi_params): #method = 'rand' or 'even' (multiple freq behavior calculator)
  selected_cols = select_eval_cols(working_df, multi_params)

  multi_freq_behavior = {}
  for selected_point in tqdm(selected_cols):
    freq_behavior = calc_freq_behavior(working_df, selected_point)
    selected_v = [v for v in freq_behavior.keys()]

    selected_d = {}
    for data in freq_behavior.values():
      for k, v in data.items():
        selected_d[k] = v

    multi_freq_behavior[selected_v[0]] = selected_d
  return multi_freq_behavior

# %%
def freq_dict_to_df(multi_freq_behavior):
  distances = [x*80 for x in range(1, 26)]
  freq_mean_data = {'distances':distances}
  freq_std_data = {'distances':distances}

  for header, distances_dict in multi_freq_behavior.items():
    col_data_mean = []
    col_data_std = []
    for distance, results in distances_dict.items():
      col_data_mean.append(results[0])
      col_data_std.append(results[1])
    freq_mean_data[header] = col_data_mean
    freq_std_data[header] = col_data_std

  freq_mean_df = pd.DataFrame(freq_mean_data)
  freq_std_df = pd.DataFrame(freq_std_data)
  
  return freq_mean_df, freq_std_df

# %% [markdown]
# ## Pearson Correletion

# %%
#eval_method = 'avg' or 'min' or 'max'

def pearson_matrix(working_df , source_sample_id):
  distances = [x*80 for x in range(1, 26)]
  result_data = {'source/target': distances}
  
  for target_dist in tqdm(distances): # loop all distances available
    min_result_target = []
    avg_result_target = []
    max_result_target = []
    for source_dist in distances: # loop all distances available
      source_df = working_df[(working_df['Distance_km'] == source_dist) & (working_df['PBRS_id'] == source_sample_id)]# select data of source (distance and sample_id) 
      source_data = source_df.iloc[0, 6:source_df.shape[1]].tolist()
      pearson_values = []
      for target_sample_id in working_df['PBRS_id'].unique(): # loop all samples id to then exclude the source sample id
        if target_sample_id != source_sample_id:
          target_df = working_df[(working_df['Distance_km'] == target_dist) & (working_df['PBRS_id'] == target_sample_id)] # select data of target
          target_data = target_df.iloc[0, 6:target_df.shape[1]].tolist()
          pearson_values.append(round(pearsonr(source_data, target_data)[0], 5)) # pearson correlation
      
      avg_result_target.append(np.mean(pearson_values))    
      max_result_target.append(np.max(pearson_values))
      min_result_target.append(np.min(pearson_values))
      
    result_data['min_'+str(target_dist)] = min_result_target
    result_data['avg_'+str(target_dist)] = avg_result_target
    result_data['max_'+str(target_dist)] = max_result_target

  pearson_matrix_df = pd.DataFrame.from_dict(result_data)
  #pearson_matrix_df = pearson_matrix_df.set_index('source/target')

  return pearson_matrix_df, result_data

# %% [markdown]
# ## Mean/std analysis

# %%
def calc_freq_behavior(working_df, selected_point): # Individual freq calculator
  extra_data = working_df.iloc[:, 0:6]
  freq_selected = working_df.iloc[:, selected_point+6]

  freq_data_df = pd.merge(extra_data, freq_selected, left_index=True, right_index=True)
  freq_data_df['Distance_km'] = freq_data_df['Distance_km'].astype(int)

  headers = list(freq_data_df.columns.values)
  selected_val = round(float(headers[-1]), 5)

  distances = [x*80 for x in range(1, 26)]
  freq_behavior = {}
  f_behavior = {}

  for dist in distances: # loop all distances available

    distance_df = freq_data_df[(freq_data_df['Distance_km'] == dist)] # select all the row with current eval distance
    freq_distance_vals = distance_df[str(selected_val)].tolist()

    freq_mean = np.mean(freq_distance_vals)
    freq_std = np.std(freq_distance_vals)
    results = (freq_mean, freq_std)
    f_behavior[dist] = results
  freq_behavior[selected_val] = f_behavior
  return freq_behavior

# %%
def calc_freq_behavior_v2(working_df, amt_of_selected_point): # Individual freq calculator
  extra_data = working_df.iloc[:, 0:6]

  distances = [x*80 for x in range(1, 26)]

  std_combined = []
  for dist in distances: # loop all distances available
    std_all = []
    for val_idx in range(0, amt_of_selected_point):

      freq_selected = working_df.iloc[:, val_idx+6]
      freq_data_df = pd.merge(extra_data, freq_selected, left_index=True, right_index=True)
      freq_data_df['Distance_km'] = freq_data_df['Distance_km'].astype(int)

      headers = list(freq_data_df.columns.values)
      selected_val = round(float(headers[-1]), 5)
      
      distance_df = freq_data_df[(freq_data_df['Distance_km'] == dist)] # select all the row with current eval distance
      freq_distance_vals = distance_df[str(selected_val)].tolist()

      freq_std = np.std(freq_distance_vals)
      std_all.append(freq_std)
      std_avg = round(np.average(std_all), 5)
    std_combined.append(std_avg)


  data = {'source/target':distances, 'std':std_combined}
 
  # Create DataFrame
  std_df = pd.DataFrame(data)
  return std_df

# %%
# Get features 
def get_features(eval_freq_data_df, amt_sel_points):
  # get pearson values
  pearson_matrix_df, result_data = pearson_matrix(eval_freq_data_df, source_sample_id=1)

  # get std values
  std_df = calc_freq_behavior_v2(eval_freq_data_df, amt_of_selected_point = amt_sel_points)

  final_df = pd.merge(pearson_matrix_df, std_df, on = "source/target", how = "inner")
  return final_df

# %%
def train_test_split(working_df, amt_train = 0.8):
  print('Creating train/test split:')
  num_sample_train = math.ceil((working_df.shape[1]-6)*amt_train)
  num_sample_test = (working_df.shape[1]-6) - num_sample_train

  multi_params = ('rand', num_sample_train)  # (evenly separate points(other option 'rand'for randomly selected points), mount of points to be selected)
  multi_freq_behavior = multiple_freq_analyzer(working_df, multi_params)

  eval_points = select_eval_cols(working_df, multi_params) # get indexes of of points to be evaluated
  real_eval_idx = [eval_point+6 for eval_point in eval_points]

  extra_data = working_df.iloc[:, 0:6]
  eval_freq_df = working_df.iloc[:, real_eval_idx]
  train_df = pd.merge(extra_data, eval_freq_df, left_index=True, right_index=True) #df we only eval freqs TRAIN

  test_df= working_df.copy()
  test_df.drop(test_df.columns[real_eval_idx], axis=1, inplace=True) # df without eval freqs TEST
  return train_df, test_df

# %% [markdown]
# ## Run train/test split

# %%
input_path = path + "/Spectrum/CNN/working_df.csv"

working_df = pd.read_csv(input_path)
working_df['Distance_km'] = working_df['Distance_km'].astype(int)

train_df, test_df = train_test_split(working_df, amt_train = 0.8)
# Out:
# Creating train/test split:
# 100%|██████████| 1654/1654 [00:27<00:00, 60.18it/s]

# %%
print('------------------------------')
# Get features 
print('Calculating features for train set:')
train_features_df = get_features(train_df, train_df.shape[1]-6)
print('------------------------------')
print('Calculating features for test set:')
test_features_df = get_features(test_df, test_df.shape[1]-6)
# Out:
# ------------------------------
# Calculating features for train set:
# 100%|██████████| 25/25 [00:21<00:00,  1.14it/s]
# ------------------------------
# Calculating features for test set:
# 100%|██████████| 25/25 [00:12<00:00,  1.94it/s]

# %%
train_features_df.to_csv(path+'/Spectrum/CNN/training_data_DNN.csv', index=False)

# %%
test_features_df.to_csv(path+'/Spectrum/CNN/testing_data_DNN.csv', index=False)

# %% [markdown]
# # Neural Network

# %% [markdown]
# #New Train/Test Split

# %%
input_path = path + "/Spectrum/CNN/working_df.csv"

working_df = pd.read_csv(input_path)
working_df['Distance_km'] = working_df['Distance_km'].astype(int)

# %%
print(working_df.shape)
# Out:
# (325, 2073)

# %%
def get_idx_train_test_split(working_df, trainingProp = 0.8):
  rows_mixed=np.random.permutation(working_df.shape[0])

  training_amt = math.ceil(working_df.shape[0]*trainingProp)
  testing_amt = working_df.shape[0] - training_amt

  rows_training = rows_mixed[:training_amt]
  rows_testing = rows_mixed[-testing_amt:]

  return rows_training, rows_testing

# %%
rows_training, rows_testing = get_idx_train_test_split(working_df, trainingProp = 0.8)

# %%
for train_idx in rows_training:
  
  data_X=working_df.iloc[train_idx,6:working_df.shape[1]]
  print(data_X)

  break
# Out:
# -32.15625   -20.512812
# -32.125     -21.346687
# -32.09375   -21.605308
# -32.0625    -23.014087
# -32.03125   -22.794589
#                ...
# 32.28125    -27.803574
# 32.3125     -30.151370
# 32.34375    -26.650385
# 32.375      -24.613101
# 32.40625    -22.074098
# Name: 172, Length: 2067, dtype: float64

# %%
def train_test_split_v2(working_df, amt_train = 0.8):
  print('Creating train/test split:')
  num_sample_train = math.ceil((working_df.shape[1]-6)*amt_train)
  num_sample_test = (working_df.shape[1]-6) - num_sample_train

  multi_params = ('rand', num_sample_train)  # (evenly separate points(other option 'rand'for randomly selected points), mount of points to be selected)
  multi_freq_behavior = multiple_freq_analyzer(working_df, multi_params)

  eval_points = select_eval_cols(working_df, multi_params) # get indexes of of points to be evaluated
  real_eval_idx = [eval_point+6 for eval_point in eval_points]

  extra_data = working_df.iloc[:, 0:6]
  eval_freq_df = working_df.iloc[:, real_eval_idx]
  train_df = pd.merge(extra_data, eval_freq_df, left_index=True, right_index=True) #df we only eval freqs TRAIN

  test_df= working_df.copy()
  test_df.drop(test_df.columns[real_eval_idx], axis=1, inplace=True) # df without eval freqs TEST
  return train_df, test_df

# %% [markdown]
# ## Pre-processing

# %%
training_df=pd.read_csv(path+'/Spectrum/CNN/training_data_DNN.csv')

Y = training_df.iloc[:, 0].to_numpy().reshape(-1,1)
X = training_df.iloc[:, 1:training_df.shape[1]]

sc_input = MinMaxScaler()
sc_output = MinMaxScaler()
Y_train = sc_output.fit_transform(Y) # convert distances to values from 0 to 1
X_train = sc_input.fit_transform(X) # convert features to values from 0 to 1

# %% [markdown]
# ## Model

# %%
'''
from keras.models import Sequential
from keras.layers import Dense,Conv2D, Flatten
from keras.wrappers.scikit_learn import KerasRegressor
from keras.callbacks import EarlyStopping


def ann():
    model = Sequential()
    model.add(Dense(76, input_dim = 76, activation = 'tanh'))
    model.add(Dense(38,activation='tanh'))
    model.add(Dense(19,activation='tanh'))
    model.add(Dense(1))
    model.compile(loss ='mean_squared_error',optimizer = 'RMSprop')
    return model


model_ann = KerasRegressor(build_fn=ann,epochs=5000,batch_size=32)

start_time = time.time()
callback = EarlyStopping(monitor='loss', patience=500)
model_ann.fit(X_train, Y_train, callbacks=[callback])
time_train_ann = time.time() - start_time
'''
# Out:
# "\nfrom keras.models import Sequential\nfrom keras.layers import Dense,Conv2D, Flatten\nfrom keras.wrappers.scikit_learn import KerasRegressor\nfrom keras.callbacks import EarlyStopping\n\n\ndef ann():\n    model = Sequential()\n    model.add(Dense(76, input_dim = 76, activation = 'tanh'))\n    model.add(Dense(38,activation='tanh'))\n    model.add(Dense(19,activation='tanh'))\n    model.add(Dense(1))\n    model.compile(loss ='mean_squared_error',optimizer = 'RMSprop')\n    return model\n\n\nmodel_ann = KerasRegressor(build_fn=ann,epochs=5000,batch_size=32)\n\nstart_time = time.time()\ncallback = EarlyStopping(monitor='loss', patience=500)\nmodel_ann.fit(X_train, Y_train, callbacks=[callback])\ntime_train_ann = time.time() - start_time\n"

# %%
from keras.models import Sequential
from keras.layers import Dense,Conv2D, Flatten
from keras.wrappers.scikit_learn import KerasRegressor
from keras.callbacks import EarlyStopping


def ann():
    model = Sequential()
    model.add(Dense(60, input_dim = 76, activation = 'relu'))
    model.add(Dense(30,activation='relu'))
    model.add(Dense(20,activation='sigmoid'))
    model.add(Dense(1,activation='sigmoid'))
    model.compile(loss ='mean_squared_error',optimizer = 'RMSprop')
    return model


model_ann = KerasRegressor(build_fn=ann,epochs=5000,batch_size=32)

start_time = time.time()
callback = EarlyStopping(monitor='loss', patience=500)
model_ann.fit(X_train, Y_train, callbacks=[callback])
time_train_ann = time.time() - start_time
# Out:
# Streaming output truncated to the last 5000 lines.
# 1/1 [==============================] - 0s 7ms/step - loss: 5.4960e-05
# Epoch 2502/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.4955e-05
# Epoch 2503/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.4726e-05
# Epoch 2504/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.4378e-05
# Epoch 2505/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.4031e-05
# Epoch 2506/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3741e-05
# Epoch 2507/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3583e-05
# Epoch 2508/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3455e-05
# Epoch 2509/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.3363e-05
# Epoch 2510/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.3295e-05
# Epoch 2511/5000
# 1/1 [==============================] - 0s 17ms/step - loss: 5.3251e-05
# Epoch 2512/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 5.3213e-05
# Epoch 2513/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.3177e-05
# Epoch 2514/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.3155e-05
# Epoch 2515/5000
# 1/1 [==============================] - 0s 18ms/step - loss: 5.3149e-05
# Epoch 2516/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 5.3177e-05
# Epoch 2517/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.3237e-05
# Epoch 2518/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 5.3318e-05
# Epoch 2519/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 5.3413e-05
# Epoch 2520/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3514e-05
# Epoch 2521/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3590e-05
# Epoch 2522/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.3648e-05
# Epoch 2523/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.3789e-05
# Epoch 2524/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.4437e-05
# Epoch 2525/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.5255e-05
# Epoch 2526/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.6353e-05
# Epoch 2527/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 5.8130e-05
# Epoch 2528/5000
# 1/1 [==============================] - 0s 17ms/step - loss: 6.0705e-05
# Epoch 2529/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 6.3878e-05
# Epoch 2530/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 6.7752e-05
# Epoch 2531/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 7.1753e-05
# Epoch 2532/5000
# 1/1 [==============================] - 0s 15ms/step - loss: 8.0154e-05
# Epoch 2533/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 8.5718e-05
# Epoch 2534/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 8.5699e-05
# Epoch 2535/5000
# 1/1 [==============================] - 0s 15ms/step - loss: 7.8051e-05
# Epoch 2536/5000
# 1/1 [==============================] - 0s 17ms/step - loss: 6.6873e-05
# Epoch 2537/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.6929e-05
# Epoch 2538/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 5.2703e-05
# Epoch 2539/5000
# 1/1 [==============================] - 0s 16ms/step - loss: 5.4867e-05
# Epoch 2540/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 6.0533e-05
# Epoch 2541/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 6.5958e-05
# Epoch 2542/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 6.7460e-05
# Epoch 2543/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 6.4172e-05
# Epoch 2544/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 5.8402e-05
# Epoch 2545/5000
# 1/1 [==============================] - 0s 16ms/step - loss: 5.3732e-05
# Epoch 2546/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 5.2530e-05
# Epoch 2547/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.4533e-05
# Epoch 2548/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.7557e-05
# Epoch 2549/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 5.9219e-05
# Epoch 2550/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.8753e-05
# Epoch 2551/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 5.6360e-05
# Epoch 2552/5000
# 1/1 [==============================] - 0s 17ms/step - loss: 5.3656e-05
# Epoch 2553/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.2200e-05
# Epoch 2554/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.2488e-05
# Epoch 2555/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3820e-05
# Epoch 2556/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.5062e-05
# Epoch 2557/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.5494e-05
# Epoch 2558/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.4759e-05
# Epoch 2559/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3378e-05
# Epoch 2560/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.2164e-05
# Epoch 2561/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1704e-05
# Epoch 2562/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.2027e-05
# Epoch 2563/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.2706e-05
# Epoch 2564/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.3210e-05
# Epoch 2565/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3292e-05
# Epoch 2566/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.3058e-05
# Epoch 2567/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.2513e-05
# Epoch 2568/5000
# 1/1 [==============================] - 0s 17ms/step - loss: 5.1913e-05
# Epoch 2569/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.1462e-05
# Epoch 2570/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 5.1257e-05
# Epoch 2571/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.1289e-05
# Epoch 2572/5000
# 1/1 [==============================] - 0s 15ms/step - loss: 5.1463e-05
# Epoch 2573/5000
# 1/1 [==============================] - 0s 15ms/step - loss: 5.1668e-05
# Epoch 2574/5000
# 1/1 [==============================] - 0s 15ms/step - loss: 5.1796e-05
# Epoch 2575/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 5.1786e-05
# Epoch 2576/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 5.1692e-05
# Epoch 2577/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 5.1534e-05
# Epoch 2578/5000
# 1/1 [==============================] - 0s 17ms/step - loss: 5.1333e-05
# Epoch 2579/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 5.1121e-05
# Epoch 2580/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 5.0950e-05
# Epoch 2581/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 5.0833e-05
# Epoch 2582/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0751e-05
# Epoch 2583/5000
# 1/1 [==============================] - 0s 21ms/step - loss: 5.0716e-05
# Epoch 2584/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 5.0708e-05
# Epoch 2585/5000
# 1/1 [==============================] - 0s 16ms/step - loss: 5.0718e-05
# Epoch 2586/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0738e-05
# Epoch 2587/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0768e-05
# Epoch 2588/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 5.0821e-05
# Epoch 2589/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 5.0845e-05
# Epoch 2590/5000
# 1/1 [==============================] - 0s 16ms/step - loss: 5.0799e-05
# Epoch 2591/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0688e-05
# Epoch 2592/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0556e-05
# Epoch 2593/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0428e-05
# Epoch 2594/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.0333e-05
# Epoch 2595/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0277e-05
# Epoch 2596/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.0237e-05
# Epoch 2597/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.0216e-05
# Epoch 2598/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0213e-05
# Epoch 2599/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0241e-05
# Epoch 2600/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0316e-05
# Epoch 2601/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0444e-05
# Epoch 2602/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0605e-05
# Epoch 2603/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 5.0962e-05
# Epoch 2604/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.1254e-05
# Epoch 2605/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.1428e-05
# Epoch 2606/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.1455e-05
# Epoch 2607/5000
# 1/1 [==============================] - 0s 15ms/step - loss: 5.1430e-05
# Epoch 2608/5000
# 1/1 [==============================] - 0s 15ms/step - loss: 5.1359e-05
# Epoch 2609/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 5.1286e-05
# Epoch 2610/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1132e-05
# Epoch 2611/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0842e-05
# Epoch 2612/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0510e-05
# Epoch 2613/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 5.0167e-05
# Epoch 2614/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9882e-05
# Epoch 2615/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9699e-05
# Epoch 2616/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9594e-05
# Epoch 2617/5000
# 1/1 [==============================] - 0s 16ms/step - loss: 4.9574e-05
# Epoch 2618/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 4.9598e-05
# Epoch 2619/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 4.9666e-05
# Epoch 2620/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 4.9755e-05
# Epoch 2621/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9874e-05
# Epoch 2622/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0050e-05
# Epoch 2623/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0366e-05
# Epoch 2624/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1439e-05
# Epoch 2625/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.2836e-05
# Epoch 2626/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.5186e-05
# Epoch 2627/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.7407e-05
# Epoch 2628/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.9426e-05
# Epoch 2629/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 6.0528e-05
# Epoch 2630/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.0570e-05
# Epoch 2631/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.9387e-05
# Epoch 2632/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.7387e-05
# Epoch 2633/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.4861e-05
# Epoch 2634/5000
# 1/1 [==============================] - 0s 19ms/step - loss: 5.2384e-05
# Epoch 2635/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.0474e-05
# Epoch 2636/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9336e-05
# Epoch 2637/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.8992e-05
# Epoch 2638/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.9299e-05
# Epoch 2639/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9977e-05
# Epoch 2640/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.1019e-05
# Epoch 2641/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 5.2467e-05
# Epoch 2642/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.4396e-05
# Epoch 2643/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.7115e-05
# Epoch 2644/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 6.0561e-05
# Epoch 2645/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 6.5329e-05
# Epoch 2646/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 6.9043e-05
# Epoch 2647/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 6.9485e-05
# Epoch 2648/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 6.7462e-05
# Epoch 2649/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.1987e-05
# Epoch 2650/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.5308e-05
# Epoch 2651/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.0297e-05
# Epoch 2652/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 4.8620e-05
# Epoch 2653/5000
# 1/1 [==============================] - 0s 15ms/step - loss: 5.0167e-05
# Epoch 2654/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.3595e-05
# Epoch 2655/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 5.6791e-05
# Epoch 2656/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.7870e-05
# Epoch 2657/5000
# 1/1 [==============================] - 0s 21ms/step - loss: 5.6398e-05
# Epoch 2658/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 5.3291e-05
# Epoch 2659/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0200e-05
# Epoch 2660/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 4.8480e-05
# Epoch 2661/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 4.8560e-05
# Epoch 2662/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.9906e-05
# Epoch 2663/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 5.1455e-05
# Epoch 2664/5000
# 1/1 [==============================] - 0s 17ms/step - loss: 5.2361e-05
# Epoch 2665/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.3269e-05
# Epoch 2666/5000
# 1/1 [==============================] - 0s 17ms/step - loss: 5.2858e-05
# Epoch 2667/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 5.1385e-05
# Epoch 2668/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.9614e-05
# Epoch 2669/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 4.8333e-05
# Epoch 2670/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.7919e-05
# Epoch 2671/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 4.8294e-05
# Epoch 2672/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.9082e-05
# Epoch 2673/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 4.9856e-05
# Epoch 2674/5000
# 1/1 [==============================] - 0s 16ms/step - loss: 5.0496e-05
# Epoch 2675/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0604e-05
# Epoch 2676/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0063e-05
# Epoch 2677/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.9205e-05
# Epoch 2678/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.8400e-05
# Epoch 2679/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.7819e-05
# Epoch 2680/5000
# 1/1 [==============================] - 0s 18ms/step - loss: 4.7583e-05
# Epoch 2681/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.7677e-05
# Epoch 2682/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 4.7950e-05
# Epoch 2683/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.8215e-05
# Epoch 2684/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 4.8338e-05
# Epoch 2685/5000
# 1/1 [==============================] - 0s 16ms/step - loss: 4.8288e-05
# Epoch 2686/5000
# 1/1 [==============================] - 0s 17ms/step - loss: 4.8070e-05
# Epoch 2687/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.7780e-05
# Epoch 2688/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 4.7501e-05
# Epoch 2689/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.7303e-05
# Epoch 2690/5000
# 1/1 [==============================] - 0s 15ms/step - loss: 4.7190e-05
# Epoch 2691/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.7161e-05
# Epoch 2692/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.7183e-05
# Epoch 2693/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.7246e-05
# Epoch 2694/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.7378e-05
# Epoch 2695/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.7606e-05
# Epoch 2696/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.7924e-05
# Epoch 2697/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.8320e-05
# Epoch 2698/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.9217e-05
# Epoch 2699/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.0025e-05
# Epoch 2700/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0379e-05
# Epoch 2701/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0218e-05
# Epoch 2702/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9750e-05
# Epoch 2703/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.8978e-05
# Epoch 2704/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.8124e-05
# Epoch 2705/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.7374e-05
# Epoch 2706/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.6871e-05
# Epoch 2707/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.6663e-05
# Epoch 2708/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 4.6707e-05
# Epoch 2709/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 4.6939e-05
# Epoch 2710/5000
# 1/1 [==============================] - 0s 15ms/step - loss: 4.7319e-05
# Epoch 2711/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.7758e-05
# Epoch 2712/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.8183e-05
# Epoch 2713/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 4.8628e-05
# Epoch 2714/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 4.9031e-05
# Epoch 2715/5000
# 1/1 [==============================] - 0s 15ms/step - loss: 4.9605e-05
# Epoch 2716/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.0057e-05
# Epoch 2717/5000
# 1/1 [==============================] - 0s 15ms/step - loss: 5.0446e-05
# Epoch 2718/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0489e-05
# Epoch 2719/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.0254e-05
# Epoch 2720/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.9619e-05
# Epoch 2721/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.8755e-05
# Epoch 2722/5000
# 1/1 [==============================] - 0s 16ms/step - loss: 4.7838e-05
# Epoch 2723/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 4.7069e-05
# Epoch 2724/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 4.6500e-05
# Epoch 2725/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.6171e-05
# Epoch 2726/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 4.6064e-05
# Epoch 2727/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.6135e-05
# Epoch 2728/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.6316e-05
# Epoch 2729/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.6578e-05
# Epoch 2730/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.6937e-05
# Epoch 2731/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.7379e-05
# Epoch 2732/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.8015e-05
# Epoch 2733/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.8753e-05
# Epoch 2734/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0162e-05
# Epoch 2735/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.1748e-05
# Epoch 2736/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3563e-05
# Epoch 2737/5000
# 1/1 [==============================] - 0s 15ms/step - loss: 5.4864e-05
# Epoch 2738/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.5515e-05
# Epoch 2739/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.5244e-05
# Epoch 2740/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.4418e-05
# Epoch 2741/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.2845e-05
# Epoch 2742/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0808e-05
# Epoch 2743/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 4.8713e-05
# Epoch 2744/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.7014e-05
# Epoch 2745/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 4.5943e-05
# Epoch 2746/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.5564e-05
# Epoch 2747/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.5773e-05
# Epoch 2748/5000
# 1/1 [==============================] - 0s 15ms/step - loss: 4.6425e-05
# Epoch 2749/5000
# 1/1 [==============================] - 0s 17ms/step - loss: 4.7509e-05
# Epoch 2750/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.8955e-05
# Epoch 2751/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0397e-05
# Epoch 2752/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 5.1543e-05
# Epoch 2753/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.2019e-05
# Epoch 2754/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 5.1775e-05
# Epoch 2755/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.1799e-05
# Epoch 2756/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.1109e-05
# Epoch 2757/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 5.0059e-05
# Epoch 2758/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.8744e-05
# Epoch 2759/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.7594e-05
# Epoch 2760/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.6534e-05
# Epoch 2761/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.5733e-05
# Epoch 2762/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 4.5293e-05
# Epoch 2763/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.5129e-05
# Epoch 2764/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 4.5170e-05
# Epoch 2765/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.5345e-05
# Epoch 2766/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.5618e-05
# Epoch 2767/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.5946e-05
# Epoch 2768/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.6324e-05
# Epoch 2769/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.6750e-05
# Epoch 2770/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.7195e-05
# Epoch 2771/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.7672e-05
# Epoch 2772/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.8173e-05
# Epoch 2773/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.8697e-05
# Epoch 2774/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.9251e-05
# Epoch 2775/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.9818e-05
# Epoch 2776/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0451e-05
# Epoch 2777/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.1018e-05
# Epoch 2778/5000
# 1/1 [==============================] - 0s 15ms/step - loss: 5.1538e-05
# Epoch 2779/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.1620e-05
# Epoch 2780/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.1140e-05
# Epoch 2781/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 5.0182e-05
# Epoch 2782/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 4.9228e-05
# Epoch 2783/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 4.7994e-05
# Epoch 2784/5000
# 1/1 [==============================] - 0s 16ms/step - loss: 4.6711e-05
# Epoch 2785/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.5620e-05
# Epoch 2786/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.4840e-05
# Epoch 2787/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.4454e-05
# Epoch 2788/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.4382e-05
# Epoch 2789/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.4585e-05
# Epoch 2790/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.4952e-05
# Epoch 2791/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.5449e-05
# Epoch 2792/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.6084e-05
# Epoch 2793/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.7321e-05
# Epoch 2794/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 4.8684e-05
# Epoch 2795/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0177e-05
# Epoch 2796/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 5.1437e-05
# Epoch 2797/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 5.2553e-05
# Epoch 2798/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.3708e-05
# Epoch 2799/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 5.4922e-05
# Epoch 2800/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.5300e-05
# Epoch 2801/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.4640e-05
# Epoch 2802/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3074e-05
# Epoch 2803/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.0692e-05
# Epoch 2804/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 4.8092e-05
# Epoch 2805/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.5923e-05
# Epoch 2806/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 4.4432e-05
# Epoch 2807/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.3769e-05
# Epoch 2808/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.3862e-05
# Epoch 2809/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 4.4486e-05
# Epoch 2810/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.5362e-05
# Epoch 2811/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.6211e-05
# Epoch 2812/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 4.6984e-05
# Epoch 2813/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 4.7405e-05
# Epoch 2814/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 4.7434e-05
# Epoch 2815/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 4.7084e-05
# Epoch 2816/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.6565e-05
# Epoch 2817/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 4.5904e-05
# Epoch 2818/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.5118e-05
# Epoch 2819/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.4374e-05
# Epoch 2820/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.3785e-05
# Epoch 2821/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.3431e-05
# Epoch 2822/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 4.3324e-05
# Epoch 2823/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.3404e-05
# Epoch 2824/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 4.3608e-05
# Epoch 2825/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 4.3875e-05
# Epoch 2826/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.4179e-05
# Epoch 2827/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.4727e-05
# Epoch 2828/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 4.5262e-05
# Epoch 2829/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 4.5812e-05
# Epoch 2830/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.6155e-05
# Epoch 2831/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 4.6306e-05
# Epoch 2832/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.6237e-05
# Epoch 2833/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.5982e-05
# Epoch 2834/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 4.5636e-05
# Epoch 2835/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.5437e-05
# Epoch 2836/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.5166e-05
# Epoch 2837/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.4789e-05
# Epoch 2838/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.4364e-05
# Epoch 2839/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.3981e-05
# Epoch 2840/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.3612e-05
# Epoch 2841/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.3302e-05
# Epoch 2842/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.3042e-05
# Epoch 2843/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.2856e-05
# Epoch 2844/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.2713e-05
# Epoch 2845/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.2626e-05
# Epoch 2846/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.2568e-05
# Epoch 2847/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 4.2529e-05
# Epoch 2848/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.2513e-05
# Epoch 2849/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.2526e-05
# Epoch 2850/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.2599e-05
# Epoch 2851/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.2787e-05
# Epoch 2852/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.3345e-05
# Epoch 2853/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.4191e-05
# Epoch 2854/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.5663e-05
# Epoch 2855/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.7329e-05
# Epoch 2856/5000
# 1/1 [==============================] - 0s 18ms/step - loss: 4.9298e-05
# Epoch 2857/5000
# 1/1 [==============================] - 0s 16ms/step - loss: 5.1673e-05
# Epoch 2858/5000
# 1/1 [==============================] - 0s 17ms/step - loss: 5.5282e-05
# Epoch 2859/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 5.9048e-05
# Epoch 2860/5000
# 1/1 [==============================] - 0s 27ms/step - loss: 6.2478e-05
# Epoch 2861/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 6.4807e-05
# Epoch 2862/5000
# 1/1 [==============================] - 0s 16ms/step - loss: 6.5378e-05
# Epoch 2863/5000
# 1/1 [==============================] - 0s 17ms/step - loss: 6.3320e-05
# Epoch 2864/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 5.9441e-05
# Epoch 2865/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 5.3968e-05
# Epoch 2866/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.8405e-05
# Epoch 2867/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 4.4219e-05
# Epoch 2868/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.2285e-05
# Epoch 2869/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 4.2558e-05
# Epoch 2870/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.4353e-05
# Epoch 2871/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 4.6622e-05
# Epoch 2872/5000
# 1/1 [==============================] - 0s 15ms/step - loss: 4.8471e-05
# Epoch 2873/5000
# 1/1 [==============================] - 0s 19ms/step - loss: 4.9666e-05
# Epoch 2874/5000
# 1/1 [==============================] - 0s 15ms/step - loss: 4.9522e-05
# Epoch 2875/5000
# 1/1 [==============================] - 0s 19ms/step - loss: 4.8101e-05
# Epoch 2876/5000
# 1/1 [==============================] - 0s 16ms/step - loss: 4.5984e-05
# Epoch 2877/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 4.3905e-05
# Epoch 2878/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.2457e-05
# Epoch 2879/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.1903e-05
# Epoch 2880/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.2168e-05
# Epoch 2881/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.2970e-05
# Epoch 2882/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.3913e-05
# Epoch 2883/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.4688e-05
# Epoch 2884/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.5000e-05
# Epoch 2885/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.4810e-05
# Epoch 2886/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.4653e-05
# Epoch 2887/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 4.4081e-05
# Epoch 2888/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 4.3270e-05
# Epoch 2889/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.2465e-05
# Epoch 2890/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 4.1855e-05
# Epoch 2891/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.1534e-05
# Epoch 2892/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.1496e-05
# Epoch 2893/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 4.1667e-05
# Epoch 2894/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.1936e-05
# Epoch 2895/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.2197e-05
# Epoch 2896/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.2383e-05
# Epoch 2897/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 4.2541e-05
# Epoch 2898/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 4.2546e-05
# Epoch 2899/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.2438e-05
# Epoch 2900/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.2246e-05
# Epoch 2901/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.1981e-05
# Epoch 2902/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.1694e-05
# Epoch 2903/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.1428e-05
# Epoch 2904/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 4.1209e-05
# Epoch 2905/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.1048e-05
# Epoch 2906/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 4.0946e-05
# Epoch 2907/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.0905e-05
# Epoch 2908/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.0902e-05
# Epoch 2909/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.0928e-05
# Epoch 2910/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 4.0960e-05
# Epoch 2911/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.1069e-05
# Epoch 2912/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 4.1474e-05
# Epoch 2913/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.2255e-05
# Epoch 2914/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.3435e-05
# Epoch 2915/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.4947e-05
# Epoch 2916/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.6435e-05
# Epoch 2917/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.7663e-05
# Epoch 2918/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.8885e-05
# Epoch 2919/5000
# 1/1 [==============================] - 0s 20ms/step - loss: 4.9647e-05
# Epoch 2920/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.9856e-05
# Epoch 2921/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 4.9352e-05
# Epoch 2922/5000
# 1/1 [==============================] - 0s 15ms/step - loss: 4.8289e-05
# Epoch 2923/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 4.6703e-05
# Epoch 2924/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 4.4902e-05
# Epoch 2925/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 4.3155e-05
# Epoch 2926/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 4.1764e-05
# Epoch 2927/5000
# 1/1 [==============================] - 0s 15ms/step - loss: 4.0837e-05
# Epoch 2928/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.0389e-05
# Epoch 2929/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.0368e-05
# Epoch 2930/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 4.0663e-05
# Epoch 2931/5000
# 1/1 [==============================] - 0s 15ms/step - loss: 4.1142e-05
# Epoch 2932/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.1701e-05
# Epoch 2933/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 4.2313e-05
# Epoch 2934/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.3363e-05
# Epoch 2935/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 4.6259e-05
# Epoch 2936/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.0432e-05
# Epoch 2937/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 5.5961e-05
# Epoch 2938/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 6.3449e-05
# Epoch 2939/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 7.1228e-05
# Epoch 2940/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 7.6198e-05
# Epoch 2941/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 7.7504e-05
# Epoch 2942/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 7.0936e-05
# Epoch 2943/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.9284e-05
# Epoch 2944/5000
# 1/1 [==============================] - 0s 5ms/step - loss: 4.7587e-05
# Epoch 2945/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.0980e-05
# Epoch 2946/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 4.1209e-05
# Epoch 2947/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 4.6348e-05
# Epoch 2948/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 5.2296e-05
# Epoch 2949/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 5.5385e-05
# Epoch 2950/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 5.3924e-05
# Epoch 2951/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.8888e-05
# Epoch 2952/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.3384e-05
# Epoch 2953/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.0323e-05
# Epoch 2954/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.0660e-05
# Epoch 2955/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.3237e-05
# Epoch 2956/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 4.6923e-05
# Epoch 2957/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 5.0464e-05
# Epoch 2958/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 5.2968e-05
# Epoch 2959/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 5.3674e-05
# Epoch 2960/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 5.2497e-05
# Epoch 2961/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.9690e-05
# Epoch 2962/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.6164e-05
# Epoch 2963/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.2870e-05
# Epoch 2964/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.0622e-05
# Epoch 2965/5000
# 1/1 [==============================] - 0s 18ms/step - loss: 3.9716e-05
# Epoch 2966/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.0048e-05
# Epoch 2967/5000
# 1/1 [==============================] - 0s 19ms/step - loss: 4.1168e-05
# Epoch 2968/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.2509e-05
# Epoch 2969/5000
# 1/1 [==============================] - 0s 15ms/step - loss: 4.3594e-05
# Epoch 2970/5000
# 1/1 [==============================] - 0s 17ms/step - loss: 4.4038e-05
# Epoch 2971/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.3783e-05
# Epoch 2972/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.2929e-05
# Epoch 2973/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.1769e-05
# Epoch 2974/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.0634e-05
# Epoch 2975/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 3.9778e-05
# Epoch 2976/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 3.9327e-05
# Epoch 2977/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 3.9287e-05
# Epoch 2978/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 3.9551e-05
# Epoch 2979/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 3.9969e-05
# Epoch 2980/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.0453e-05
# Epoch 2981/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.1219e-05
# Epoch 2982/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.1604e-05
# Epoch 2983/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.1291e-05
# Epoch 2984/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.0528e-05
# Epoch 2985/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 3.9682e-05
# Epoch 2986/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 3.9094e-05
# Epoch 2987/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 3.8940e-05
# Epoch 2988/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 3.9154e-05
# Epoch 2989/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 3.9528e-05
# Epoch 2990/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 3.9821e-05
# Epoch 2991/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 3.9891e-05
# Epoch 2992/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 3.9703e-05
# Epoch 2993/5000
# 1/1 [==============================] - 0s 19ms/step - loss: 3.9531e-05
# Epoch 2994/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 3.9280e-05
# Epoch 2995/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 3.9059e-05
# Epoch 2996/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 3.8903e-05
# Epoch 2997/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 3.8763e-05
# Epoch 2998/5000
# 1/1 [==============================] - 0s 18ms/step - loss: 3.8646e-05
# Epoch 2999/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 3.8600e-05
# Epoch 3000/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 3.8560e-05
# Epoch 3001/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 3.8524e-05
# Epoch 3002/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 3.8510e-05
# Epoch 3003/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 3.8515e-05
# Epoch 3004/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 3.8539e-05
# Epoch 3005/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 3.8587e-05
# Epoch 3006/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 3.8695e-05
# Epoch 3007/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 3.9008e-05
# Epoch 3008/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 3.9496e-05
# Epoch 3009/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.0273e-05
# Epoch 3010/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.1384e-05
# Epoch 3011/5000
# 1/1 [==============================] - 0s 16ms/step - loss: 4.3034e-05
# Epoch 3012/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.5134e-05
# Epoch 3013/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 4.7439e-05
# Epoch 3014/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.9205e-05
# Epoch 3015/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.9048e-05
# Epoch 3016/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.6511e-05
# Epoch 3017/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 4.2832e-05
# Epoch 3018/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 3.9712e-05
# Epoch 3019/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 3.8241e-05
# Epoch 3020/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 3.8614e-05
# Epoch 3021/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.0149e-05
# Epoch 3022/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.1738e-05
# Epoch 3023/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.2658e-05
# Epoch 3024/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.3745e-05
# Epoch 3025/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 4.3539e-05
# Epoch 3026/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.2120e-05
# Epoch 3027/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 4.0240e-05
# Epoch 3028/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 3.8695e-05
# Epoch 3029/5000
# 1/1 [==============================] - 0s 17ms/step - loss: 3.8042e-05
# Epoch 3030/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 3.8292e-05
# Epoch 3031/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 3.9100e-05
# Epoch 3032/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 3.9909e-05
# Epoch 3033/5000
# 1/1 [==============================] - 0s 17ms/step - loss: 4.0286e-05
# Epoch 3034/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 4.0118e-05
# Epoch 3035/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 3.9506e-05
# Epoch 3036/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 3.8730e-05
# Epoch 3037/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 3.8076e-05
# Epoch 3038/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 3.7755e-05
# Epoch 3039/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 3.7779e-05
# Epoch 3040/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 3.8013e-05
# Epoch 3041/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 3.8341e-05
# Epoch 3042/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 3.8644e-05
# Epoch 3043/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 3.8780e-05
# Epoch 3044/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 3.8691e-05
# Epoch 3045/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 3.8410e-05
# Epoch 3046/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 3.8043e-05
# Epoch 3047/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 3.7708e-05
# Epoch 3048/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 3.7489e-05
# Epoch 3049/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 3.7396e-05
# Epoch 3050/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 3.7421e-05
# Epoch 3051/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 3.7516e-05
# Epoch 3052/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 3.7638e-05
# Epoch 3053/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 3.7764e-05
# Epoch 3054/5000
# 1/1 [==============================] - 0s 19ms/step - loss: 3.7853e-05
# ...
# Epoch 4816/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.4203e-05
# Epoch 4817/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 6.0416e-05
# Epoch 4818/5000
# 1/1 [==============================] - 0s 19ms/step - loss: 7.8887e-05
# Epoch 4819/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 9.6389e-05
# Epoch 4820/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0432e-04
# Epoch 4821/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 9.8670e-05
# Epoch 4822/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 7.6902e-05
# Epoch 4823/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 4.4658e-05
# Epoch 4824/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.9725e-05
# Epoch 4825/5000
# 1/1 [==============================] - 0s 17ms/step - loss: 1.6285e-05
# Epoch 4826/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 3.0667e-05
# Epoch 4827/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 4.7084e-05
# Epoch 4828/5000
# 1/1 [==============================] - 0s 16ms/step - loss: 5.0883e-05
# Epoch 4829/5000
# 1/1 [==============================] - 0s 15ms/step - loss: 3.8799e-05
# Epoch 4830/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 2.2117e-05
# Epoch 4831/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 1.4741e-05
# Epoch 4832/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 2.0057e-05
# Epoch 4833/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 3.0081e-05
# Epoch 4834/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 3.5290e-05
# Epoch 4835/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 3.0699e-05
# Epoch 4836/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 2.0781e-05
# Epoch 4837/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4762e-05
# Epoch 4838/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.6740e-05
# Epoch 4839/5000
# 1/1 [==============================] - 0s 16ms/step - loss: 2.2645e-05
# Epoch 4840/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 2.5605e-05
# Epoch 4841/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 2.2818e-05
# Epoch 4842/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.7450e-05
# Epoch 4843/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4550e-05
# Epoch 4844/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 1.5961e-05
# Epoch 4845/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.9133e-05
# Epoch 4846/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 2.0470e-05
# Epoch 4847/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.9022e-05
# Epoch 4848/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.6116e-05
# Epoch 4849/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4410e-05
# Epoch 4850/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5038e-05
# Epoch 4851/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.6765e-05
# Epoch 4852/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.7585e-05
# Epoch 4853/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.6717e-05
# Epoch 4854/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.5132e-05
# Epoch 4855/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4287e-05
# Epoch 4856/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4687e-05
# Epoch 4857/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.5614e-05
# Epoch 4858/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.6016e-05
# Epoch 4859/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5532e-05
# Epoch 4860/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.4677e-05
# Epoch 4861/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.4212e-05
# Epoch 4862/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4406e-05
# Epoch 4863/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4891e-05
# Epoch 4864/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 1.5124e-05
# Epoch 4865/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4894e-05
# Epoch 4866/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 1.4439e-05
# Epoch 4867/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 1.4151e-05
# Epoch 4868/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4204e-05
# Epoch 4869/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4449e-05
# Epoch 4870/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4605e-05
# Epoch 4871/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4525e-05
# Epoch 4872/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4291e-05
# Epoch 4873/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4102e-05
# Epoch 4874/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.4079e-05
# Epoch 4875/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.4189e-05
# Epoch 4876/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.4294e-05
# Epoch 4877/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4314e-05
# Epoch 4878/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4261e-05
# Epoch 4879/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4151e-05
# Epoch 4880/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4043e-05
# Epoch 4881/5000
# 1/1 [==============================] - 0s 18ms/step - loss: 1.4011e-05
# Epoch 4882/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.4051e-05
# Epoch 4883/5000
# 1/1 [==============================] - 0s 21ms/step - loss: 1.4106e-05
# Epoch 4884/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 1.4120e-05
# Epoch 4885/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4080e-05
# Epoch 4886/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 1.4015e-05
# Epoch 4887/5000
# 1/1 [==============================] - 0s 15ms/step - loss: 1.3968e-05
# Epoch 4888/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 1.3961e-05
# Epoch 4889/5000
# 1/1 [==============================] - 0s 15ms/step - loss: 1.3982e-05
# Epoch 4890/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4002e-05
# Epoch 4891/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 1.3996e-05
# Epoch 4892/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.3966e-05
# Epoch 4893/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3930e-05
# Epoch 4894/5000
# 1/1 [==============================] - 0s 17ms/step - loss: 1.3905e-05
# Epoch 4895/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 1.3899e-05
# Epoch 4896/5000
# 1/1 [==============================] - 0s 17ms/step - loss: 1.3906e-05
# Epoch 4897/5000
# 1/1 [==============================] - 0s 15ms/step - loss: 1.3911e-05
# Epoch 4898/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3907e-05
# Epoch 4899/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3891e-05
# Epoch 4900/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3868e-05
# Epoch 4901/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.3847e-05
# Epoch 4902/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3833e-05
# Epoch 4903/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3827e-05
# Epoch 4904/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3826e-05
# Epoch 4905/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3824e-05
# Epoch 4906/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3818e-05
# Epoch 4907/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3807e-05
# Epoch 4908/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3793e-05
# Epoch 4909/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 1.3778e-05
# Epoch 4910/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3766e-05
# Epoch 4911/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3761e-05
# Epoch 4912/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3753e-05
# Epoch 4913/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3751e-05
# Epoch 4914/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3749e-05
# Epoch 4915/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3754e-05
# Epoch 4916/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 1.3766e-05
# Epoch 4917/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3779e-05
# Epoch 4918/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3790e-05
# Epoch 4919/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3781e-05
# Epoch 4920/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3754e-05
# Epoch 4921/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3722e-05
# Epoch 4922/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3691e-05
# Epoch 4923/5000
# 1/1 [==============================] - 0s 16ms/step - loss: 1.3671e-05
# Epoch 4924/5000
# 1/1 [==============================] - 0s 14ms/step - loss: 1.3664e-05
# Epoch 4925/5000
# 1/1 [==============================] - 0s 16ms/step - loss: 1.3665e-05
# Epoch 4926/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 1.3669e-05
# Epoch 4927/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.3670e-05
# Epoch 4928/5000
# 1/1 [==============================] - 0s 18ms/step - loss: 1.3665e-05
# Epoch 4929/5000
# 1/1 [==============================] - 0s 16ms/step - loss: 1.3653e-05
# Epoch 4930/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.3637e-05
# Epoch 4931/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3619e-05
# Epoch 4932/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3604e-05
# Epoch 4933/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3591e-05
# Epoch 4934/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 1.3582e-05
# Epoch 4935/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3576e-05
# Epoch 4936/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3575e-05
# Epoch 4937/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3577e-05
# Epoch 4938/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3585e-05
# Epoch 4939/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3603e-05
# Epoch 4940/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3636e-05
# Epoch 4941/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 1.3693e-05
# Epoch 4942/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.3754e-05
# Epoch 4943/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3783e-05
# Epoch 4944/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.3776e-05
# Epoch 4945/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3735e-05
# Epoch 4946/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3675e-05
# Epoch 4947/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3608e-05
# Epoch 4948/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3548e-05
# Epoch 4949/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3502e-05
# Epoch 4950/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3474e-05
# Epoch 4951/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3462e-05
# Epoch 4952/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3463e-05
# Epoch 4953/5000
# 1/1 [==============================] - 0s 16ms/step - loss: 1.3477e-05
# Epoch 4954/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 1.3510e-05
# Epoch 4955/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3551e-05
# Epoch 4956/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3611e-05
# Epoch 4957/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3666e-05
# Epoch 4958/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3712e-05
# Epoch 4959/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3743e-05
# Epoch 4960/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3757e-05
# Epoch 4961/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3755e-05
# Epoch 4962/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3731e-05
# Epoch 4963/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3823e-05
# Epoch 4964/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4084e-05
# Epoch 4965/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.4534e-05
# Epoch 4966/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.5009e-05
# Epoch 4967/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5488e-05
# Epoch 4968/5000
# 1/1 [==============================] - 0s 12ms/step - loss: 1.6093e-05
# Epoch 4969/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.6605e-05
# Epoch 4970/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.6948e-05
# Epoch 4971/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.7081e-05
# Epoch 4972/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.7038e-05
# Epoch 4973/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.6829e-05
# Epoch 4974/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.6477e-05
# Epoch 4975/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 1.6031e-05
# Epoch 4976/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.5537e-05
# Epoch 4977/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.5050e-05
# Epoch 4978/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.4597e-05
# Epoch 4979/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.4202e-05
# Epoch 4980/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3871e-05
# Epoch 4981/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3629e-05
# Epoch 4982/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.3460e-05
# Epoch 4983/5000
# 1/1 [==============================] - 0s 15ms/step - loss: 1.3356e-05
# Epoch 4984/5000
# 1/1 [==============================] - 0s 21ms/step - loss: 1.3308e-05
# Epoch 4985/5000
# 1/1 [==============================] - 0s 13ms/step - loss: 1.3302e-05
# Epoch 4986/5000
# 1/1 [==============================] - 0s 18ms/step - loss: 1.3330e-05
# Epoch 4987/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3379e-05
# Epoch 4988/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3441e-05
# Epoch 4989/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3508e-05
# Epoch 4990/5000
# 1/1 [==============================] - 0s 6ms/step - loss: 1.3585e-05
# Epoch 4991/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3664e-05
# Epoch 4992/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3754e-05
# Epoch 4993/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3951e-05
# Epoch 4994/5000
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4187e-05
# Epoch 4995/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4505e-05
# Epoch 4996/5000
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4871e-05
# Epoch 4997/5000
# 1/1 [==============================] - 0s 7ms/step - loss: 1.5288e-05
# Epoch 4998/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.5769e-05
# Epoch 4999/5000
# 1/1 [==============================] - 0s 10ms/step - loss: 1.6328e-05
# Epoch 5000/5000
# 1/1 [==============================] - 0s 9ms/step - loss: 1.6989e-05

# %% [markdown]
# ## Test Model

# %%
testing_df=pd.read_csv(path+'/Spectrum/CNN/testing_data_DNN.csv')

Y = testing_df.iloc[:, 0].to_numpy().reshape(-1,1)
X = testing_df.iloc[:, 1:testing_df.shape[1]]


sc_input = MinMaxScaler()
sc_output = MinMaxScaler()
Y_test = sc_output.fit_transform(Y) # convert distances to values from 0 to 1
X_test = sc_input.fit_transform(X) # convert features to values from 0 to 1

# %%
start_time = time.time()
Y_test_pred=model_ann.predict(X_test)

time_eval_ann=time.time()-start_time

real=list(list(zip(*Y_test))[0])

#real=list(map(list, zip(*Y_train)))
pred=list(Y_test_pred)
print(pred)

dist_min=sc_output.data_min_[0] # 80
dist_max=sc_output.data_max_[0] # 2000

#np.add = add values in a array
#np.multiply multiple values in a array
print(real)
real_abs=np.add(dist_min,np.multiply((dist_max-dist_min),real)) # convert back to distances values from scalar
real_abs=[int(np.round(i)) for i in real_abs]
#print(real_abs)
pred_abs=np.add(dist_min,np.multiply((dist_max-dist_min),pred)) # convert back to distances values from scalar
#print(pred_abs)

#np.divide = divide values in a array
error=np.divide(np.abs(np.subtract(np.array(real_abs),np.array(pred_abs))),np.array(real_abs))

res=pd.DataFrame({"dist":real_abs,"pred":pred_abs,"error":error})
display(res)
res.to_csv("results_pme_supervisedFeatures.csv", header=True, index=False)
plt.plot(real_abs,error,'bo')
plt.show()
# Out:
# [0.07028741, 0.6638993, 0.12155324, 0.032971352, 0.1463036, 0.15908286, 0.5612916, 0.024032414, 0.34875447, 0.26912248, 0.7586977, 0.90840733, 0.65681756, 0.122752726, 0.5702201, 0.808482, 0.8786784, 0.07322547, 0.90188146, 0.93113136, 0.9659319, 0.95768565, 0.96336055, 0.45081288, 0.92163026]
# [0.0, 0.041666666666666664, 0.08333333333333334, 0.125, 0.16666666666666669, 0.20833333333333334, 0.25, 0.29166666666666663, 0.3333333333333333, 0.375, 0.41666666666666663, 0.4583333333333333, 0.49999999999999994, 0.5416666666666667, 0.5833333333333334, 0.625, 0.6666666666666667, 0.7083333333333334, 0.75, 0.7916666666666667, 0.8333333333333334, 0.875, 0.9166666666666667, 0.9583333333333334, 1.0]
#     dist         pred     error
# 0     80   214.951813  1.686898
# 1    160  1354.686646  7.466792
# 2    240   313.382233  0.305759
# 3    320   143.304993  0.552172
# 4    400   360.902893  0.097743
# 5    480   385.439087  0.197002
# 6    560  1157.679810  1.067285
# 7    640   126.142235  0.802903
# 8    720   749.608582  0.041123
# 9    800   596.715149  0.254106
# 10   880  1536.699585  0.746250
# 11   960  1824.142090  0.900148
# 12  1040  1341.089722  0.289509
# 13  1120   315.685242  0.718138
# 14  1200  1174.822632  0.020981
# 15  1280  1632.285400  0.275223
# 16  1360  1767.062500  0.299311
# 17  1440   220.592896  0.846810
# 18  1520  1811.612427  0.191850
# 19  1600  1867.772217  0.167358
# 20  1680  1934.589233  0.151541
# 21  1760  1918.756470  0.090203
# 22  1840  1929.652222  0.048724
# 23  1920   945.560730  0.507520
# 24  2000  1849.530151  0.075235
