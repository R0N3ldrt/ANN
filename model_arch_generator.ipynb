# %% [markdown]
# <a href="https://colab.research.google.com/github/R0N3ldrt/Thesis/blob/main/model_arch_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Load Enviroment

# %%
# BLOQUE PARA USAR DESDE COLAB

# Google drive loading as work station for local-usage of the files.
from google.colab import drive
drive.mount('/content/gdrive',force_remount= True)

#-----------------------------------------------------------------------------
# Out:
# Mounted at /content/gdrive

# %%
# Lista para cambiar los paths rapido.
workers = ["Ronald", "Local"]

# Change the number to change the paths.
worker = workers[0]

if worker == "Ronald":
  path = "/content/gdrive/MyDrive/Thesis_Workstation/ANN_dataset"
else: path = os.getcwd()

# %% [markdown]
# # Create NN architecture

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.utils.vis_utils import plot_model

model = Sequential()
model.add(Dense(76, input_dim = 2561, activation = 'tanh'))
model.add(Dense(38,activation='tanh'))
model.add(Dense(19,activation='tanh'))
model.add(Dense(1))



filename = 'distance_predictor'
plot_model(model, to_file=path+'/Spectrum/NN/model_arch/'+str(filename)+'.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# # csv to latex

# %%
import pandas as pd

df = pd.read_csv(path+'/Spectrum/NN/AE_results/attacked/comb_res.csv')
df.to_latex(path+'/Spectrum/NN/AE_results/attacked/comb_res.tex', index=False)
